# %%
# !pip install pandas numpy
# Out:
# Requirement already satisfied: pandas in ./.conda/lib/python3.11/site-packages (2.2.3)
# Requirement already satisfied: numpy in ./.conda/lib/python3.11/site-packages (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.conda/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.conda/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.conda/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in ./.conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
import numpy as np

# %%
import os, io

def read_file_content(file_path):
    with open(file_path, 'r') as f:
        content = f.read()
    return content

def walk_over_files_with_ext(directory, extensions):
    for root, _, files in os.walk(directory):
        for file in files:
            if any(file.endswith(ext) for ext in extensions):
                file_path = os.path.join(root, file)
                yield (file_path, read_file_content(file_path))

def walk_over_files(directory):
    for root, _, files in os.walk(directory):
        for file in files:
            file_path = os.path.join(root, file)
            yield (file_path, read_file_content(file_path))

# %%
def parse_topic_file(content):
    extracted = {}
    lines = content.strip().split('\n')
    for line in lines:
        line = line.strip()
        if line.startswith("Topic:"):
            extracted['Topic'] = line[len("Topic:"):].strip()
        elif line.startswith("Title:"):
            extracted['Title'] = line[len("Title:"):].strip()
        elif line.startswith("Objective:"):
            extracted['Objective'] = line[len("Objective:"):].strip()
        elif line.startswith("Objectives:"):
            extracted['Objective'] = line[len("Objectives:"):].strip()

    if not (
        'Topic' in extracted and 
        'Title' in extracted and 
        'Objective' in extracted
        ):
        print(Warning(f'Could not parse topic {extracted["Topic"]}'))
        return None
        
    return pd.DataFrame([{ 
                    'topic_id': extracted['Topic'], 
                    'topic_title': extracted['Title'], 
                    'topic_objective': extracted['Objective']
                }])
        
def parse_qrels_file(content):
    try:
        data_io = io.StringIO(content)
        pids_df = pd.read_csv(data_io, sep='\s+', header=None, 
                              names=['topic_id', 'irrelevant_1', 'PID', 'irrelevant_2'])

        del pids_df['irrelevant_1']
        del pids_df['irrelevant_2']

        return pids_df
    except Exception as e:
        print('Could not pares qrel file', e)
        return None


training_data_paths = [
    'data/DATA2019/Training/DTA',
    'data/DATA2019/Training/Intervention'
]

topics_df = pd.DataFrame([], columns= ['topic_id', 'topic_title', 'topic_objective'])
qrels_df = pd.DataFrame([], columns= ['topic_id', 'PID'])

for path in training_data_paths:
    for (path, content) in walk_over_files(path):
        if path.split('/')[-2] == 'topics':
            topic_row = parse_topic_file(content)

            if topic_row is not None:
                topics_df = pd.concat([topics_df, topic_row], ignore_index=True)

        if path.split('/')[-2] == 'qrels':
            qrels_row = parse_qrels_file(content)

            if qrels_row is not None:
                qrels_df = pd.concat([qrels_df, qrels_row], ignore_index=True)

            
df = pd.merge(topics_df, qrels_df, on='topic_id', how='left')

df
# Out:
# Could not parse topic CD011134
#        topic_id                                        topic_title  \
# 0      CD010653              First rank symptoms for schizophrenia
# 1      CD010653              First rank symptoms for schizophrenia
# 2      CD010653              First rank symptoms for schizophrenia
# 3      CD010653              First rank symptoms for schizophrenia
# 4      CD010653              First rank symptoms for schizophrenia
# ...         ...                                                ...
# 10838  CD008018  Adjuvant gonadotropin‐releasing hormone analog...
# 10839  CD008018  Adjuvant gonadotropin‐releasing hormone analog...
# 10840  CD008018  Adjuvant gonadotropin‐releasing hormone analog...
# 10841  CD008018  Adjuvant gonadotropin‐releasing hormone analog...
# 10842  CD008018  Adjuvant gonadotropin‐releasing hormone analog...
#
#                                          topic_objective       PID
# 0      To determine the diagnostic accuracy of one or...   7625188
# 1      To determine the diagnostic accuracy of one or...  12109956
# 2      To determine the diagnostic accuracy of one or...   7103677
# 3      To determine the diagnostic accuracy of one or...    679137
# 4      To determine the diagnostic accuracy of one or...  11772849
# ...                                                  ...       ...
# 10838                                                     17159194
# 10839                                                     27217453
# 10840                                                     28911092
# 10841                                                     19153828
# 10842                                                     29332135
#
# [10843 rows x 4 columns]
